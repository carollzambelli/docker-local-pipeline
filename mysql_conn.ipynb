# %%
import mysql.connector

# %%
con = mysql.connector.connect(
            user='root', password='root', port="3306", database='db')

# %%
con

# %%
cursor = con.cursor()
cursor.execute('Select * FROM cadastro_raw')
cadastro = cursor.fetchall()
cadastro
# Out:
# [(1,
#   'female',
#   'corina.louis@example.com',
#   '075 542 97 96',
#   '078 501 05 48',
#   'CH',
#   'Mademoiselle',
#   'Corina',
#   'Louis',
#   '2402',
#   'Rue Baraban',
#   'Obersteckholz',
#   'Valais',
#   'Switzerland',
#   '4940',
#   '-62.6291',
#   '154.0165',
#   '+8:00',
#   'Beijing, Perth, Singapore, Hong Kong',
#   '395d36ad-af03-49e7-bfe5-f6722471874f',
#   'greenwolf455',
#   'sylveste',
#   '0boI5D97',
#   '7ab8ef6cce9a1f73e101691cce04ef43',
#   '0716303ab193cf8786603afff184a9629e749896',
#   'f9794d02bc13036fb0b403990bb1057895241965b6f78e4dc650c29e6396b578',
#   '1971-04-19T18:05:13.033Z',
#   '53',
#   '2005-02-04T04:46:18.704Z',
#   '19',
#   'AVS',
#   '756.4900.0882.53',
#   'https://randomuser.me/api/portraits/women/17.jpg',
#   'https://randomuser.me/api/portraits/med/women/17.jpg',
#   'https://randomuser.me/api/portraits/thumb/women/17.jpg',
#   datetime.datetime(2024, 6, 14, 15, 5, 26)),
#  (2,
#   'female',
#   'jessica.hansen@example.com',
# ...
